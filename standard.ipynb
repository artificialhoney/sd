# %%
# !rm -rf giger && git clone https://github.com/artificialhoney/giger.git && cd giger && pip install -e . && pip install git+https://github.com/ai-forever/Real-ESRGAN.git && pip install ansible

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !ln -s /content/drive/MyDrive/sd/ $PWD/

# %%
# !sed -i 's/from torchvision\.transforms\.functional_tensor import rgb_to_grayscale/from torchvision\.transforms\.functional import rgb_to_grayscale/' /usr/local/lib/python3.10/dist-packages/basicsr/data/degradations.py

# %%
# !SD_PROJECT=ivory_ebony_tattooed source sd/src/scripts/init.sh && bash sd/src/scripts/render.sh

# %%
# !cd giger && git fetch && git reset --hard origin/main # && pip install -e .

# %%
# %%bash
#
# GLOB="*_*.png"
# TARGET_MIN=0 # 0
# TARGET_COUNT=2
# PROJECT="ivory_ebony_tattooed/pool"
# FACE="sd/assets/faces/palina/dirne.png"
#
# for filename in sd/output/$PROJECT/_selected/$GLOB; do
#     IFS='_' read -ra SUFFIX <<< $(basename "$filename")
#     IFS='.' read -ra INDEX <<< ${SUFFIX[1]}
#     giger roop -f $FACE -i $filename -t "${INDEX[0]}" -e -o $(basename "$filename").swapped.png
# done
