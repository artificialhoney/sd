# %%
# !rm -rf giger && git clone https://github.com/artificialhoney/giger.git

# %%
# !pip install git+https://github.com/ai-forever/Real-ESRGAN.git

# %%
# !cd giger && pip install -e .

# %%
# !apt-get install webp

# %%
# !cd giger && git fetch && git reset --hard origin/main

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !ln -s /content/drive/MyDrive/sd/ sd

# %%
# %env SETTING="Highly detailed wide angle shot of the magnificent modern architecture of the beautiful metropole St. Petersburg in a warm summer night"
# %env MUSE="Highly detailed portrait of a fat big-breasted magnificent sexy romantic russian ginger-haired Ballerina dancing through the street"
# %env OBJECT="Highly detailed full body shot of a strong bad heavily full armored hyper-modern combat stealth doom death Warrior in dark gray teflon carbon"

# %env PROJECT=ah

# !bash sd/src/scripts/standard.sh -x "$SETTING" -m "$MUSE" -o "$OBJECT" "magnificent sunset and light"
