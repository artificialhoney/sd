# %%
# !rm -rf giger && git clone https://github.com/artificialhoney/giger.git

# %%
# !pip install git+https://github.com/ai-forever/Real-ESRGAN.git git+https://github.com/LIAAD/yake

# %%
# !cd giger && pip install -e .

# %%
# !apt-get install webp

# %%
# !cd giger && git fetch && git reset --hard origin/main

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !ln -s /content/drive/MyDrive/sd/ sd

# %%
# !cp sd/src/batches/ax.py /root/.ipython/profile_default/startup/startup.py

# %%
# !bash sd/src/scripts/render.sh -x "$SETTING" -m "$MUSE" -o "$OBJECT"  -c 4 -s 10 "magnificent sunset and light" "photorealistic panorama"

# %%
# !bash sd/src/scripts/convert.sh

# %%
# !bash sd/src/scripts/layout.sh

# %%
# !bash sd/src/scripts/meta.sh
